# %% [markdown]
# For this assignment, you will replicate the supplier selection analysis we covered in class on a new dataset. Specifically, in this dataset you will be evaluating suppliers of refridgerated warehouse services.
#
# The following code block imports some necessary libraries.

# %%
import pathlib

import re

import numpy as np
import pandas as pd

from sklearn import preprocessing

import OM527_functions as omf

# %% [markdown]
# The following code block defines the `custom_grouper` function that we used in the notebook covering the concept of spend analysis.

# %%
def custom_grouper(df, agg_dict, groupby_columns):
    '''
    This function groups the provided DataFrame, df, by the columns
    specified in the groupby_columns argument. The aggregations specified
    in the agg_dict dictionary are applied. Also, each numeric column in the 
    aggregated DataFrame is used to create a proportion column. The aggregated data
    is returned as a DataFrame sorted by the keys of the agg_dict
    dictionary, in the order they are specified, i.e., first key
    has a higher sort priority than the second, etc...
    '''
    
    grouped_df = df.groupby(groupby_columns).agg(agg_dict)
    
    grouped_df.columns = ['_'.join(col).strip() for col in grouped_df.columns.values]
    
    numeric_columns = grouped_df.select_dtypes(include='number').columns.tolist()

    for column in numeric_columns:
        grouped_df[f'{column}_proportion'] = (grouped_df[column]/grouped_df[column].sum())
        
    grouped_df = grouped_df.sort_values(numeric_columns)

    return grouped_df

# %% [markdown]
# 1) Read in the supplier data stored in the file `rw_supplier_data.csv` and print the first five rows. **(5 points)**

# %%
wb = pd.read_csv("data/rw_supplier_data.csv")

wb.head()
# Out:
#             Company Name         City State  ZIP Code  Primary NAICS  \
# 0  Advanced Mini Storage    Northport    AL     35473         531130
# 1              Americold   Montgomery    AL     36108         493120
# 2    Americold Logistics  Albertville    AL     35951         493120
# 3    Americold Logistics   Birmingham    AL     35204         541611
# 4    Americold Logistics       Mobile    AL     36615         493120
#
#                            Primary NAICS Description  \
# 0     Lessors Of Miniwarehouses & Self-Storage Units
# 1                 Refrigerated Warehousing & Storage
# 2                 Refrigerated Warehousing & Storage
# 3  Administrative & General Mgmt Consulting Services
# 4                 Refrigerated Warehousing & Storage
#
#    Location Employee Size Actual Location Sales Volume Actual  \
# 0                              3                     $400,000
# 1                             30                   $2,818,000
# 2                             32                   $2,645,000
# 3                              6                     $592,000
# 4                             25                   $2,239,000
#
#   Type of Business   Square Footage Credit Score Alpha Saturday Open  \
# 0          Private    2,500 - 4,999                 B+        Closed
# 1          Private  20,000 - 39,999                 A+           NaN
# 2          Private  20,000 - 39,999                 A+           NaN
# 3          Private    2,500 - 4,999                  A           NaN
# 4          Private  20,000 - 39,999                 A+           NaN
#
#   Sunday Open
# 0      Closed
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %% [markdown]
# 2) Limit the data so that it only includes companies with an NAICS decription of "Refrigerated Warehousing & Storage". **(5 points)**

# %%
wb = wb.loc[wb['Primary NAICS Description'] == "Refrigerated Warehousing & Storage"]

# %%
wb
# Out:
#                    Company Name         City State  ZIP Code  Primary NAICS  \
# 1                     Americold   Montgomery    AL     36108         493120
# 2           Americold Logistics  Albertville    AL     35951         493120
# 4           Americold Logistics       Mobile    AL     36615         493120
# 5               Bayou Ice Boxes    Irvington    AL     36544         493120
# 9         Decatur Business Park      Decatur    AL     35603         493120
# ..                          ...          ...   ...       ...            ...
# 146  Nashville Refrigerated Svc      Lebanon    TN     37090         493120
# 151               Southernbelle       Martin    TN     38237         493120
# 154  United States Cold Storage    Covington    TN     38019         493120
# 155  United States Cold Storage    La Vergne    TN     37086         493120
# 156  United States Cold Storage       Smyrna    TN     37167         493120
#
#               Primary NAICS Description  Location Employee Size Actual  \
# 1    Refrigerated Warehousing & Storage                             30
# 2    Refrigerated Warehousing & Storage                             32
# 4    Refrigerated Warehousing & Storage                             25
# 5    Refrigerated Warehousing & Storage                             23
# 9    Refrigerated Warehousing & Storage                             23
# ..                                  ...                            ...
# 146  Refrigerated Warehousing & Storage                             90
# 151  Refrigerated Warehousing & Storage                              7
# 154  Refrigerated Warehousing & Storage                             45
# 155  Refrigerated Warehousing & Storage                             20
# 156  Refrigerated Warehousing & Storage                             25
#
#     Location Sales Volume Actual Type of Business   Square Footage  \
# 1                     $2,818,000          Private  20,000 - 39,999
# 2                     $2,645,000          Private  20,000 - 39,999
# 4                     $2,239,000          Private  20,000 - 39,999
# 5                     $2,060,000          Private  10,000 - 19,999
# 9                     $1,969,000          Private  40,000 - 99,999
# ..                           ...              ...              ...
# 146                   $7,582,000          Private  40,000 - 99,999
# 151                   $1,113,000          Private    2,500 - 4,999
# 154                   $3,293,000          Private  20,000 - 39,999
# 155                   $2,057,000          Private  20,000 - 39,999
# 156                   $2,428,000          Private  20,000 - 39,999
#
#     Credit Score Alpha  Saturday Open    Sunday Open
# 1                   A+            NaN            NaN
# 2                   A+            NaN            NaN
# 4                   A+            NaN            NaN
# 5                    A         Closed         Closed
# 9                    A  Open 24 Hours  Open 24 Hours
# ..                 ...            ...            ...
# 146                 A+            NaN            NaN
# 151                 B+            NaN            NaN
# 154                 A+            NaN            NaN
# 155                 A+            NaN            NaN
# 156                 A+            NaN            NaN
#
# [67 rows x 13 columns]

# %% [markdown]
# 3) Convert the data in the `Location Sales Volumne Actual` column to a numeric format. **(10 points)**

# %%
#df3 = wb

money_to_num = lambda x: re.sub("[^0-9]", "", x)

wb['Location Sales Volume Actual'] = pd.to_numeric(wb['Location Sales Volume Actual'].apply(money_to_num))
wb['Location Sales Volume Actual']
# Out:
# 1      2818000
# 2      2645000
# 4      2239000
# 5      2060000
# 9      1969000
#         ...
# 146    7582000
# 151    1113000
# 154    3293000
# 155    2057000
# 156    2428000
# Name: Location Sales Volume Actual, Length: 67, dtype: int64

# %% [markdown]
# 4) Use the `Credit Score Alpha` column to assign values to a new column named `Credit Score Num` based on the following mapping:
#
# - A+ = 1
# - A = 0.8
# - B+ = 0.6
# - B = 0.4
# - C+ = 0.2
#
# **(5 points)**

# %%
my_dict = {
    'A+' : 1,
    'A' : 0.8,
    'B+' : 0.6,
    'B' : 0.4,
    'C+' : 0.2,
}

#df4 = wb

wb['Credit Score Num'] = wb['Credit Score Alpha'].map(my_dict)

print(wb[['Credit Score Num','Credit Score Alpha']]) # Won't let me pass it as a tuple cause it's deprecated octothorpe trash
# Out:
#      Credit Score Num Credit Score Alpha
# 1                 1.0                 A+
# 2                 1.0                 A+
# 4                 1.0                 A+
# 5                 0.8                  A
# 9                 0.8                  A
# ..                ...                ...
# 146               1.0                 A+
# 151               0.6                 B+
# 154               1.0                 A+
# 155               1.0                 A+
# 156               1.0                 A+
#
# [67 rows x 2 columns]

# %% [markdown]
# 5) Create a column called `Location Score` that equals 1 if the company is in Alabama and 0.5 if the company is located elsewhere. **(10 points)**

# %%
#df5 = wb

tacos = lambda x: 1 if str(x) == "AL" else 0.5 # I forget the type coercion behavior

wb['Location Score'] = wb['State'].apply(tacos)
wb[['Location Score', 'State']]
# Out:
#      Location Score State
# 1               1.0    AL
# 2               1.0    AL
# 4               1.0    AL
# 5               1.0    AL
# 9               1.0    AL
# ..              ...   ...
# 146             0.5    TN
# 151             0.5    TN
# 154             0.5    TN
# 155             0.5    TN
# 156             0.5    TN
#
# [67 rows x 2 columns]

# %% [markdown]
# 6) Recall that some companies operated multiple locations in the data we used to demonstrate supplier selection methods. We only want one observation for each company in our final data. Ensure that the current data only includes one entry for each company. If a company has multiple entries, reconstruct the data so that we **average the values in the `Credit Score Num` and `Location Score` columns for companies with multiple locations. Also, sum the values in the `Location Sales Volume Actual` column for companies with multiple locations.** **(10 points)**

# %%
groupby_columns6 = ['Company Name']

agg_dict6 = {
    'Credit Score Num':['mean'],
    'Location Score':['mean'],
    'Location Sales Volume Actual':['sum'],
}

df6 = wb.groupby(groupby_columns6).agg(agg_dict6)
df6.columns = agg_dict6.keys()
df6 = df6.reset_index()
#print(wb[wb['Company Name'] == "ACBL"])
df6
# Out:
#                       Company Name  Credit Score Num  Location Score  \
# 0                   Agro Merchants               0.8        0.500000
# 1          Albany Cold Storage LLC               1.0        0.500000
# 2   Ameri Peanut Growers Cold Stge               1.0        0.500000
# 3            American Cold Storage               1.0        0.500000
# 4                        Americold               1.0        1.000000
# 5                   Americold Corp               0.6        0.500000
# 6              Americold Logistics               1.0        0.625000
# 7          Americold Logistics LLC               1.0        0.500000
# 8      B & B Transport Warehousing               0.6        0.500000
# 9                  Bayou Ice Boxes               0.8        1.000000
# 10   Birdsong Peanuts Cold Storage               0.4        0.500000
# 11         Briggs Frozen Warehouse               0.8        0.500000
# 12                Burris Logistics               1.0        0.500000
# 13               CCA Resources LLC               0.4        0.500000
# 14        Claxton Cold Storage Inc               1.0        0.500000
# 15                Cold Storage Inc               0.6        0.500000
# 16             Custom Cold Storage               0.8        0.500000
# 17           Decatur Business Park               0.8        1.000000
# 18             Eskimo Cold Storage               0.8        0.500000
# 19          Execuplex Mini Storage               0.4        1.000000
# 20         Georgia Cold Storage Co               0.7        0.500000
# 21        Georgia Cold Storage Inc               0.8        0.500000
# 22   Gulf States Refrigerated Stge               1.0        1.000000
# 23          Iberville Cold Storage               0.8        0.500000
# 24            Jackson Cold Storage               0.8        0.500000
# 25                  Jerich USA Inc               1.0        0.500000
# 26     Lineage Flint River Svc Inc               1.0        0.500000
# 27        Memphis Cold Storage LLC               0.4        0.500000
# 28      Mid-South Distributors Inc               1.0        1.000000
# 29            Moultre Cold Storage               0.2        0.500000
# 30      Nashville Refrigerated Svc               1.0        0.500000
# 31             Nordic Cold Storage               0.9        0.583333
# 32                Nordic Logistics               1.0        0.500000
# 33           Preferred Freezer Svc               1.0        0.500000
# 34   Savannah Portside Frigeration               0.8        0.500000
# 35                         Seaonus               1.0        1.000000
# 36                   Serv-Cold LLC               0.8        1.000000
# 37     Southeast Food Distribution               0.6        0.500000
# 38                Southern Customs               0.8        1.000000
# 39                   Southernbelle               0.7        0.500000
# 40      Southernbelle Refrigerated               0.8        0.500000
# 41      Storage Rentals Of America               0.4        0.500000
# 42     Sun States Refrigerated Svc               0.8        1.000000
# 43             Thomas Cold Storage               0.6        0.500000
# 44      United States Cold Storage               1.0        0.500000
# 45                  Universal Pure               0.8        0.500000
# 46                   Waken Meat Co               0.8        0.500000
# 47       Westside Community Market               0.6        0.500000
#
#     Location Sales Volume Actual
# 0                        1317000
# 1                        1080000
# 2                       10846000
# 3                        1174000
# 4                        2818000
# 5                         777000
# 6                       81098000
# 7                        2360000
# 8                         665000
# 9                        2060000
# 10                       1163000
# 11                        745000
# 12                       1580000
# 13                       1163000
# 14                       6853000
# 15                        479000
# 16                             0
# 17                       1969000
# 18                       1263000
# 19                        194000
# 20                       2163000
# 21                        858000
# 22                       4377000
# 23                        667000
# 24                        950000
# 25                       1580000
# 26                      11780000
# 27                        831000
# 28                       2265000
# 29                         78000
# 30                       7582000
# 31                      12643000
# 32                             0
# 33                       6204000
# 34                       1214000
# 35                       1881000
# 36                       1906000
# 37                       1014000
# 38                       1956000
# 39                       2393000
# 40                             0
# 41                       1097000
# 42                        740000
# 43                       1056000
# 44                       7778000
# 45                             0
# 46                        659000
# 47                       1580000

# %% [markdown]
# 7) Normalize the data in the `Location Sales Volume Actual` so that all values are between 0 and 1 with the lowest value in the column being assigned a value of zero and the highest value in the column being assigned a value of one. **(5 points)**

# %%
df7 = df6

sales_array = df7['Location Sales Volume Actual'].values.reshape((-1,1))

df7['Location Sales Volume Actual'] = preprocessing.MinMaxScaler().fit_transform(sales_array)

df7
# Out:
#                       Company Name  Credit Score Num  Location Score  \
# 0                   Agro Merchants               0.8        0.500000
# 1          Albany Cold Storage LLC               1.0        0.500000
# 2   Ameri Peanut Growers Cold Stge               1.0        0.500000
# 3            American Cold Storage               1.0        0.500000
# 4                        Americold               1.0        1.000000
# 5                   Americold Corp               0.6        0.500000
# 6              Americold Logistics               1.0        0.625000
# 7          Americold Logistics LLC               1.0        0.500000
# 8      B & B Transport Warehousing               0.6        0.500000
# 9                  Bayou Ice Boxes               0.8        1.000000
# 10   Birdsong Peanuts Cold Storage               0.4        0.500000
# 11         Briggs Frozen Warehouse               0.8        0.500000
# 12                Burris Logistics               1.0        0.500000
# 13               CCA Resources LLC               0.4        0.500000
# 14        Claxton Cold Storage Inc               1.0        0.500000
# 15                Cold Storage Inc               0.6        0.500000
# 16             Custom Cold Storage               0.8        0.500000
# 17           Decatur Business Park               0.8        1.000000
# 18             Eskimo Cold Storage               0.8        0.500000
# 19          Execuplex Mini Storage               0.4        1.000000
# 20         Georgia Cold Storage Co               0.7        0.500000
# 21        Georgia Cold Storage Inc               0.8        0.500000
# 22   Gulf States Refrigerated Stge               1.0        1.000000
# 23          Iberville Cold Storage               0.8        0.500000
# 24            Jackson Cold Storage               0.8        0.500000
# 25                  Jerich USA Inc               1.0        0.500000
# 26     Lineage Flint River Svc Inc               1.0        0.500000
# 27        Memphis Cold Storage LLC               0.4        0.500000
# 28      Mid-South Distributors Inc               1.0        1.000000
# 29            Moultre Cold Storage               0.2        0.500000
# 30      Nashville Refrigerated Svc               1.0        0.500000
# 31             Nordic Cold Storage               0.9        0.583333
# 32                Nordic Logistics               1.0        0.500000
# 33           Preferred Freezer Svc               1.0        0.500000
# 34   Savannah Portside Frigeration               0.8        0.500000
# 35                         Seaonus               1.0        1.000000
# 36                   Serv-Cold LLC               0.8        1.000000
# 37     Southeast Food Distribution               0.6        0.500000
# 38                Southern Customs               0.8        1.000000
# 39                   Southernbelle               0.7        0.500000
# 40      Southernbelle Refrigerated               0.8        0.500000
# 41      Storage Rentals Of America               0.4        0.500000
# 42     Sun States Refrigerated Svc               0.8        1.000000
# 43             Thomas Cold Storage               0.6        0.500000
# 44      United States Cold Storage               1.0        0.500000
# 45                  Universal Pure               0.8        0.500000
# 46                   Waken Meat Co               0.8        0.500000
# 47       Westside Community Market               0.6        0.500000
#
#     Location Sales Volume Actual
# 0                       0.016240
# 1                       0.013317
# 2                       0.133739
# 3                       0.014476
# 4                       0.034748
# 5                       0.009581
# 6                       1.000000
# 7                       0.029101
# 8                       0.008200
# 9                       0.025401
# 10                      0.014341
# 11                      0.009186
# 12                      0.019483
# 13                      0.014341
# 14                      0.084503
# 15                      0.005906
# 16                      0.000000
# 17                      0.024279
# 18                      0.015574
# 19                      0.002392
# 20                      0.026671
# 21                      0.010580
# 22                      0.053972
# 23                      0.008225
# 24                      0.011714
# 25                      0.019483
# 26                      0.145256
# 27                      0.010247
# 28                      0.027929
# 29                      0.000962
# 30                      0.093492
# 31                      0.155898
# 32                      0.000000
# 33                      0.076500
# 34                      0.014970
# 35                      0.023194
# 36                      0.023502
# 37                      0.012503
# 38                      0.024119
# 39                      0.029508
# 40                      0.000000
# 41                      0.013527
# 42                      0.009125
# 43                      0.013021
# 44                      0.095909
# 45                      0.000000
# 46                      0.008126
# 47                      0.019483

# %% [markdown]
# 8) Assume that the following weights are given for the `Credit Score Num`, `Location Sales Volume Actual`, and `Location Score` values:
# - `Credit Score Num` = 9
# - `Location Score` = 8
# - `Location Sales Volume Actual` = 5
#
# Normalize these weights and use them to determine weighted sum and weighted product scores for all of the companies. What are the top 3 companies by each scoring method? **(30 points - 10 for weight normalization, 10 for correct application of weighted sum, and 10 for correct application of weighted product)**

# %%
df8 = df7
df9 = df7

weights = {
    'Credit Score Num' : 9,
    'Location Score' : 8,
    'Location Sales Volume Actual' : 5,
}

weights = {key : value/sum(weights.values()) for key, value in weights.items()}

weights
# Out:
# {'Credit Score Num': 0.4090909090909091,
#  'Location Score': 0.36363636363636365,
#  'Location Sales Volume Actual': 0.22727272727272727}

# %%
temp = pd.Series(index = df8.index, data = 0)

for key, weight in weights.items():
    if key in df8.columns:
        temp += df8[key]*weight
    else:
        continue
        
temp.tolist()
    
df8['WS'] = temp
df8.sort_values(by = 'WS', ascending=False)
# Out:
#                       Company Name  Credit Score Num  Location Score  \
# 6              Americold Logistics               1.0        0.625000
# 22   Gulf States Refrigerated Stge               1.0        1.000000
# 4                        Americold               1.0        1.000000
# 28      Mid-South Distributors Inc               1.0        1.000000
# 35                         Seaonus               1.0        1.000000
# 9                  Bayou Ice Boxes               0.8        1.000000
# 17           Decatur Business Park               0.8        1.000000
# 38                Southern Customs               0.8        1.000000
# 36                   Serv-Cold LLC               0.8        1.000000
# 42     Sun States Refrigerated Svc               0.8        1.000000
# 26     Lineage Flint River Svc Inc               1.0        0.500000
# 2   Ameri Peanut Growers Cold Stge               1.0        0.500000
# 31             Nordic Cold Storage               0.9        0.583333
# 44      United States Cold Storage               1.0        0.500000
# 30      Nashville Refrigerated Svc               1.0        0.500000
# 14        Claxton Cold Storage Inc               1.0        0.500000
# 33           Preferred Freezer Svc               1.0        0.500000
# 7          Americold Logistics LLC               1.0        0.500000
# 12                Burris Logistics               1.0        0.500000
# 25                  Jerich USA Inc               1.0        0.500000
# 3            American Cold Storage               1.0        0.500000
# 1          Albany Cold Storage LLC               1.0        0.500000
# 32                Nordic Logistics               1.0        0.500000
# 19          Execuplex Mini Storage               0.4        1.000000
# 0                   Agro Merchants               0.8        0.500000
# 18             Eskimo Cold Storage               0.8        0.500000
# 34   Savannah Portside Frigeration               0.8        0.500000
# 24            Jackson Cold Storage               0.8        0.500000
# 21        Georgia Cold Storage Inc               0.8        0.500000
# 11         Briggs Frozen Warehouse               0.8        0.500000
# 23          Iberville Cold Storage               0.8        0.500000
# 46                   Waken Meat Co               0.8        0.500000
# 16             Custom Cold Storage               0.8        0.500000
# 45                  Universal Pure               0.8        0.500000
# 40      Southernbelle Refrigerated               0.8        0.500000
# 39                   Southernbelle               0.7        0.500000
# 20         Georgia Cold Storage Co               0.7        0.500000
# 47       Westside Community Market               0.6        0.500000
# 43             Thomas Cold Storage               0.6        0.500000
# 37     Southeast Food Distribution               0.6        0.500000
# 5                   Americold Corp               0.6        0.500000
# 8      B & B Transport Warehousing               0.6        0.500000
# 15                Cold Storage Inc               0.6        0.500000
# 10   Birdsong Peanuts Cold Storage               0.4        0.500000
# 13               CCA Resources LLC               0.4        0.500000
# 41      Storage Rentals Of America               0.4        0.500000
# 27        Memphis Cold Storage LLC               0.4        0.500000
# 29            Moultre Cold Storage               0.2        0.500000
#
#     Location Sales Volume Actual        WS
# 6                       1.000000  0.863636
# 22                      0.053972  0.784994
# 4                       0.034748  0.780625
# 28                      0.027929  0.779075
# 35                      0.023194  0.777999
# 9                       0.025401  0.696682
# 17                      0.024279  0.696427
# 38                      0.024119  0.696391
# 36                      0.023502  0.696251
# 42                      0.009125  0.692983
# 26                      0.145256  0.623922
# 2                       0.133739  0.621304
# 31                      0.155898  0.615734
# 44                      0.095909  0.612707
# 30                      0.093492  0.612157
# 14                      0.084503  0.610114
# 33                      0.076500  0.608295
# 7                       0.029101  0.597523
# 12                      0.019483  0.595337
# 25                      0.019483  0.595337
# 3                       0.014476  0.594199
# 1                       0.013317  0.593936
# 32                      0.000000  0.590909
# 19                      0.002392  0.527816
# 0                       0.016240  0.512782
# 18                      0.015574  0.512630
# 34                      0.014970  0.512493
# 24                      0.011714  0.511753
# 21                      0.010580  0.511495
# 11                      0.009186  0.511179
# 23                      0.008225  0.510960
# 46                      0.008126  0.510938
# 16                      0.000000  0.509091
# 45                      0.000000  0.509091
# 40                      0.000000  0.509091
# 39                      0.029508  0.474888
# 20                      0.026671  0.474244
# 47                      0.019483  0.431701
# 43                      0.013021  0.430232
# 37                      0.012503  0.430114
# 5                       0.009581  0.429450
# 8                       0.008200  0.429136
# 15                      0.005906  0.428615
# 10                      0.014341  0.348714
# 13                      0.014341  0.348714
# 41                      0.013527  0.348529
# 27                      0.010247  0.347783
# 29                      0.000962  0.263855

# %%
temp = pd.Series(index = df8.index, data = 0)

for key, weight in weights.items():
    if key in df8.columns:
        temp += df8[key]**weight
    else:
        continue
        
temp.tolist()
    
df8['WP'] = temp
df8.sort_values(by = 'WP', ascending=False)
print("\n\nTop 3 by Weighted Sum:\n\n")
print(df8.sort_values(by = 'WS', ascending=False).iloc[0:3])
print("\n\nTop 3 by Weighted Product:\n\n")
print(df8.sort_values(by = 'WP', ascending=False).iloc[0:3])
# Out:
# Top 3 by Weighted Sum:
#
#
#                      Company Name  Credit Score Num  Location Score  \
# 6             Americold Logistics               1.0           0.625
# 22  Gulf States Refrigerated Stge               1.0           1.000
# 4                       Americold               1.0           1.000
#
#     Location Sales Volume Actual        WS        WP
# 6                       1.000000  0.863636  2.842897
# 22                      0.053972  0.784994  2.515058
# 4                       0.034748  0.780625  2.466008
#
#
# Top 3 by Weighted Product:
#
#
#                      Company Name  Credit Score Num  Location Score  \
# 6             Americold Logistics               1.0           0.625
# 22  Gulf States Refrigerated Stge               1.0           1.000
# 4                       Americold               1.0           1.000
#
#     Location Sales Volume Actual        WS        WP
# 6                       1.000000  0.863636  2.842897
# 22                      0.053972  0.784994  2.515058
# 4                       0.034748  0.780625  2.466008

# %% [markdown]
# 9) Assume that the following preferences are given:
# - a high `Credit Score Num` is strongly more preferable than a high `Location Score`,
# - a high `Credit Score Num` is extremely more preferable than a high `Location Sales Volume Actual`, and
# - a high `Location Score` is moderately more preferable than a high `Location Sales Volume Actual`.
#
# Use these preferences to derive new weights and use these to determine updated weighted sum and weighted product scores for all companies. Again, specify the top 3 companies according to each scoring method. **(20 points)**

# %%
comparison_data = [
    [1, 5, 9],
    [0.2, 1, 3],
    [0.111, 0.333, 1],
]

index_vals = ['Credit Score Num', 'Location Score', 'Location Sales Volume Actual']

df_comp = pd.DataFrame(comparison_data, index = index_vals, columns = index_vals)

column_sums = np.sum(df_comp, axis=0)
scores_div = df_comp/column_sums

pv = np.average(scores_div, axis = 1)

# max_eigenvalue = np.inner(pv, column_sums)

# CI = (max_eigenvalue - len(pv))/(len(pv)-1)
# RI = [0, 0, 0, 0.58, 0.9, 1.12, 1.24, 1.32, 1.41]
# CR = np.round(CI/RI[len(pv)], 5)

# print(CR)

weights9 = {
    'Credit Score Num' : pv[0],
    'Location Score' : pv[1],
    'Location Sales Volume Actual' : pv[2]
}

df9
# Out:
#                       Company Name  Credit Score Num  Location Score  \
# 0                   Agro Merchants               0.8        0.500000
# 1          Albany Cold Storage LLC               1.0        0.500000
# 2   Ameri Peanut Growers Cold Stge               1.0        0.500000
# 3            American Cold Storage               1.0        0.500000
# 4                        Americold               1.0        1.000000
# 5                   Americold Corp               0.6        0.500000
# 6              Americold Logistics               1.0        0.625000
# 7          Americold Logistics LLC               1.0        0.500000
# 8      B & B Transport Warehousing               0.6        0.500000
# 9                  Bayou Ice Boxes               0.8        1.000000
# 10   Birdsong Peanuts Cold Storage               0.4        0.500000
# 11         Briggs Frozen Warehouse               0.8        0.500000
# 12                Burris Logistics               1.0        0.500000
# 13               CCA Resources LLC               0.4        0.500000
# 14        Claxton Cold Storage Inc               1.0        0.500000
# 15                Cold Storage Inc               0.6        0.500000
# 16             Custom Cold Storage               0.8        0.500000
# 17           Decatur Business Park               0.8        1.000000
# 18             Eskimo Cold Storage               0.8        0.500000
# 19          Execuplex Mini Storage               0.4        1.000000
# 20         Georgia Cold Storage Co               0.7        0.500000
# 21        Georgia Cold Storage Inc               0.8        0.500000
# 22   Gulf States Refrigerated Stge               1.0        1.000000
# 23          Iberville Cold Storage               0.8        0.500000
# 24            Jackson Cold Storage               0.8        0.500000
# 25                  Jerich USA Inc               1.0        0.500000
# 26     Lineage Flint River Svc Inc               1.0        0.500000
# 27        Memphis Cold Storage LLC               0.4        0.500000
# 28      Mid-South Distributors Inc               1.0        1.000000
# 29            Moultre Cold Storage               0.2        0.500000
# 30      Nashville Refrigerated Svc               1.0        0.500000
# 31             Nordic Cold Storage               0.9        0.583333
# 32                Nordic Logistics               1.0        0.500000
# 33           Preferred Freezer Svc               1.0        0.500000
# 34   Savannah Portside Frigeration               0.8        0.500000
# 35                         Seaonus               1.0        1.000000
# 36                   Serv-Cold LLC               0.8        1.000000
# 37     Southeast Food Distribution               0.6        0.500000
# 38                Southern Customs               0.8        1.000000
# 39                   Southernbelle               0.7        0.500000
# 40      Southernbelle Refrigerated               0.8        0.500000
# 41      Storage Rentals Of America               0.4        0.500000
# 42     Sun States Refrigerated Svc               0.8        1.000000
# 43             Thomas Cold Storage               0.6        0.500000
# 44      United States Cold Storage               1.0        0.500000
# 45                  Universal Pure               0.8        0.500000
# 46                   Waken Meat Co               0.8        0.500000
# 47       Westside Community Market               0.6        0.500000
#
#     Location Sales Volume Actual        WS        WP
# 0                       0.016240  0.688764  1.728690
# 1                       0.013317  0.838404  1.882453
# 2                       0.133739  0.838404  1.882453
# 3                       0.014476  0.838404  1.882453
# 4                       0.034748  0.928609  2.000000
# 5                       0.009581  0.539124  1.564811
# 6                       1.000000  0.860956  1.918702
# 7                       0.029101  0.838404  1.882453
# 8                       0.008200  0.539124  1.564811
# 9                       0.025401  0.778969  1.846237
# 10                      0.014341  0.389485  1.386256
# 11                      0.009186  0.688764  1.728690
# 12                      0.019483  0.838404  1.882453
# 13                      0.014341  0.389485  1.386256
# 14                      0.084503  0.838404  1.882453
# 15                      0.005906  0.539124  1.564811
# 16                      0.000000  0.688764  1.728690
# 17                      0.024279  0.778969  1.846237
# 18                      0.015574  0.688764  1.728690
# 19                      0.002392  0.479689  1.503804
# 20                      0.026671  0.613944  1.648230
# 21                      0.010580  0.688764  1.728690
# 22                      0.053972  0.928609  2.000000
# 23                      0.008225  0.688764  1.728690
# 24                      0.011714  0.688764  1.728690
# 25                      0.019483  0.838404  1.882453
# 26                      0.145256  0.838404  1.882453
# 27                      0.010247  0.389485  1.386256
# 28                      0.027929  0.928609  2.000000
# 29                      0.000962  0.239845  1.182390
# 30                      0.093492  0.838404  1.882453
# 31                      0.155898  0.778619  1.831535
# 32                      0.000000  0.838404  1.882453
# 33                      0.076500  0.838404  1.882453
# 34                      0.014970  0.688764  1.728690
# 35                      0.023194  0.928609  2.000000
# 36                      0.023502  0.778969  1.846237
# 37                      0.012503  0.539124  1.564811
# 38                      0.024119  0.778969  1.846237
# 39                      0.029508  0.613944  1.648230
# 40                      0.000000  0.688764  1.728690
# 41                      0.013527  0.389485  1.386256
# 42                      0.009125  0.778969  1.846237
# 43                      0.013021  0.539124  1.564811
# 44                      0.095909  0.838404  1.882453
# 45                      0.000000  0.688764  1.728690
# 46                      0.008126  0.688764  1.728690
# 47                      0.019483  0.539124  1.564811

# %%
temp = pd.Series(index = df9.index, data = 0)



for key, weight in weights9.items():
    if key in df9.columns:
        temp += df9[key]*weight
    else:
        continue
        
temp.tolist()
    
df9['WS'] = temp
print(temp)
df9.sort_values(by = 'WS', ascending=False)
# Out:
# 0     0.689924
# 1     0.839355
# 2     0.847952
# 3     0.839438
# 4     0.931090
# 5     0.539808
# 6     0.932347
# 7     0.840482
# 8     0.539710
# 9     0.780782
# 10    0.390508
# 11    0.689420
# 12    0.839795
# 13    0.390508
# 14    0.844437
# 15    0.539546
# 16    0.688764
# 17    0.780702
# 18    0.689876
# 19    0.479860
# 20    0.615849
# 21    0.689520
# 22    0.932462
# 23    0.689352
# 24    0.689601
# 25    0.839795
# 26    0.848774
# 27    0.390216
# 28    0.930603
# 29    0.239913
# 30    0.845079
# 31    0.789748
# 32    0.838404
# 33    0.843866
# 34    0.689833
# 35    0.930265
# 36    0.780647
# 37    0.540017
# 38    0.780691
# 39    0.616051
# 40    0.688764
# 41    0.390450
# 42    0.779620
# 43    0.540054
# 44    0.845251
# 45    0.688764
# 46    0.689345
# 47    0.540515
# dtype: float64
#                       Company Name  Credit Score Num  Location Score  \
# 22   Gulf States Refrigerated Stge               1.0        1.000000
# 6              Americold Logistics               1.0        0.625000
# 4                        Americold               1.0        1.000000
# 28      Mid-South Distributors Inc               1.0        1.000000
# 35                         Seaonus               1.0        1.000000
# 26     Lineage Flint River Svc Inc               1.0        0.500000
# 2   Ameri Peanut Growers Cold Stge               1.0        0.500000
# 44      United States Cold Storage               1.0        0.500000
# 30      Nashville Refrigerated Svc               1.0        0.500000
# 14        Claxton Cold Storage Inc               1.0        0.500000
# 33           Preferred Freezer Svc               1.0        0.500000
# 7          Americold Logistics LLC               1.0        0.500000
# 25                  Jerich USA Inc               1.0        0.500000
# 12                Burris Logistics               1.0        0.500000
# 3            American Cold Storage               1.0        0.500000
# 1          Albany Cold Storage LLC               1.0        0.500000
# 32                Nordic Logistics               1.0        0.500000
# 31             Nordic Cold Storage               0.9        0.583333
# 9                  Bayou Ice Boxes               0.8        1.000000
# 17           Decatur Business Park               0.8        1.000000
# 38                Southern Customs               0.8        1.000000
# 36                   Serv-Cold LLC               0.8        1.000000
# 42     Sun States Refrigerated Svc               0.8        1.000000
# 0                   Agro Merchants               0.8        0.500000
# 18             Eskimo Cold Storage               0.8        0.500000
# 34   Savannah Portside Frigeration               0.8        0.500000
# 24            Jackson Cold Storage               0.8        0.500000
# 21        Georgia Cold Storage Inc               0.8        0.500000
# 11         Briggs Frozen Warehouse               0.8        0.500000
# 23          Iberville Cold Storage               0.8        0.500000
# 46                   Waken Meat Co               0.8        0.500000
# 45                  Universal Pure               0.8        0.500000
# 16             Custom Cold Storage               0.8        0.500000
# 40      Southernbelle Refrigerated               0.8        0.500000
# 39                   Southernbelle               0.7        0.500000
# 20         Georgia Cold Storage Co               0.7        0.500000
# 47       Westside Community Market               0.6        0.500000
# 43             Thomas Cold Storage               0.6        0.500000
# 37     Southeast Food Distribution               0.6        0.500000
# 5                   Americold Corp               0.6        0.500000
# 8      B & B Transport Warehousing               0.6        0.500000
# 15                Cold Storage Inc               0.6        0.500000
# 19          Execuplex Mini Storage               0.4        1.000000
# 10   Birdsong Peanuts Cold Storage               0.4        0.500000
# 13               CCA Resources LLC               0.4        0.500000
# 41      Storage Rentals Of America               0.4        0.500000
# 27        Memphis Cold Storage LLC               0.4        0.500000
# 29            Moultre Cold Storage               0.2        0.500000
#
#     Location Sales Volume Actual        WS        WP
# 22                      0.053972  0.932462  2.000000
# 6                       1.000000  0.932347  1.918702
# 4                       0.034748  0.931090  2.000000
# 28                      0.027929  0.930603  2.000000
# 35                      0.023194  0.930265  2.000000
# 26                      0.145256  0.848774  1.882453
# 2                       0.133739  0.847952  1.882453
# 44                      0.095909  0.845251  1.882453
# 30                      0.093492  0.845079  1.882453
# 14                      0.084503  0.844437  1.882453
# 33                      0.076500  0.843866  1.882453
# 7                       0.029101  0.840482  1.882453
# 25                      0.019483  0.839795  1.882453
# 12                      0.019483  0.839795  1.882453
# 3                       0.014476  0.839438  1.882453
# 1                       0.013317  0.839355  1.882453
# 32                      0.000000  0.838404  1.882453
# 31                      0.155898  0.789748  1.831535
# 9                       0.025401  0.780782  1.846237
# 17                      0.024279  0.780702  1.846237
# 38                      0.024119  0.780691  1.846237
# 36                      0.023502  0.780647  1.846237
# 42                      0.009125  0.779620  1.846237
# 0                       0.016240  0.689924  1.728690
# 18                      0.015574  0.689876  1.728690
# 34                      0.014970  0.689833  1.728690
# 24                      0.011714  0.689601  1.728690
# 21                      0.010580  0.689520  1.728690
# 11                      0.009186  0.689420  1.728690
# 23                      0.008225  0.689352  1.728690
# 46                      0.008126  0.689345  1.728690
# 45                      0.000000  0.688764  1.728690
# 16                      0.000000  0.688764  1.728690
# 40                      0.000000  0.688764  1.728690
# 39                      0.029508  0.616051  1.648230
# 20                      0.026671  0.615849  1.648230
# 47                      0.019483  0.540515  1.564811
# 43                      0.013021  0.540054  1.564811
# 37                      0.012503  0.540017  1.564811
# 5                       0.009581  0.539808  1.564811
# 8                       0.008200  0.539710  1.564811
# 15                      0.005906  0.539546  1.564811
# 19                      0.002392  0.479860  1.503804
# 10                      0.014341  0.390508  1.386256
# 13                      0.014341  0.390508  1.386256
# 41                      0.013527  0.390450  1.386256
# 27                      0.010247  0.390216  1.386256
# 29                      0.000962  0.239913  1.182390

# %%
temp = pd.Series(index = df9.index, data = 0)

for key, weight in weights9.items():
    if key in df9.columns:
        temp += df9[key]**weight
    else:
        continue
        
temp.tolist()
    
df9['WP'] = temp
df9.sort_values(by = 'WP', ascending=False)
# Out:
#                       Company Name  Credit Score Num  Location Score  \
# 6              Americold Logistics               1.0        0.625000
# 22   Gulf States Refrigerated Stge               1.0        1.000000
# 4                        Americold               1.0        1.000000
# 28      Mid-South Distributors Inc               1.0        1.000000
# 35                         Seaonus               1.0        1.000000
# 26     Lineage Flint River Svc Inc               1.0        0.500000
# 2   Ameri Peanut Growers Cold Stge               1.0        0.500000
# 44      United States Cold Storage               1.0        0.500000
# 30      Nashville Refrigerated Svc               1.0        0.500000
# 14        Claxton Cold Storage Inc               1.0        0.500000
# 33           Preferred Freezer Svc               1.0        0.500000
# 31             Nordic Cold Storage               0.9        0.583333
# 7          Americold Logistics LLC               1.0        0.500000
# 12                Burris Logistics               1.0        0.500000
# 25                  Jerich USA Inc               1.0        0.500000
# 3            American Cold Storage               1.0        0.500000
# 1          Albany Cold Storage LLC               1.0        0.500000
# 9                  Bayou Ice Boxes               0.8        1.000000
# 17           Decatur Business Park               0.8        1.000000
# 38                Southern Customs               0.8        1.000000
# 36                   Serv-Cold LLC               0.8        1.000000
# 42     Sun States Refrigerated Svc               0.8        1.000000
# 0                   Agro Merchants               0.8        0.500000
# 18             Eskimo Cold Storage               0.8        0.500000
# 34   Savannah Portside Frigeration               0.8        0.500000
# 24            Jackson Cold Storage               0.8        0.500000
# 21        Georgia Cold Storage Inc               0.8        0.500000
# 11         Briggs Frozen Warehouse               0.8        0.500000
# 23          Iberville Cold Storage               0.8        0.500000
# 46                   Waken Meat Co               0.8        0.500000
# 39                   Southernbelle               0.7        0.500000
# 20         Georgia Cold Storage Co               0.7        0.500000
# 47       Westside Community Market               0.6        0.500000
# 43             Thomas Cold Storage               0.6        0.500000
# 37     Southeast Food Distribution               0.6        0.500000
# 5                   Americold Corp               0.6        0.500000
# 8      B & B Transport Warehousing               0.6        0.500000
# 15                Cold Storage Inc               0.6        0.500000
# 19          Execuplex Mini Storage               0.4        1.000000
# 13               CCA Resources LLC               0.4        0.500000
# 10   Birdsong Peanuts Cold Storage               0.4        0.500000
# 41      Storage Rentals Of America               0.4        0.500000
# 27        Memphis Cold Storage LLC               0.4        0.500000
# 32                Nordic Logistics               1.0        0.500000
# 29            Moultre Cold Storage               0.2        0.500000
# 16             Custom Cold Storage               0.8        0.500000
# 40      Southernbelle Refrigerated               0.8        0.500000
# 45                  Universal Pure               0.8        0.500000
#
#     Location Sales Volume Actual        WS        WP
# 6                       1.000000  0.932347  2.918702
# 22                      0.053972  0.932462  2.811873
# 4                       0.034748  0.931090  2.786748
# 28                      0.027929  0.930603  2.774573
# 35                      0.023194  0.930265  2.764368
# 26                      0.145256  0.848774  2.753785
# 2                       0.133739  0.847952  2.748662
# 44                      0.095909  0.845251  2.728343
# 30                      0.093492  0.845079  2.726803
# 14                      0.084503  0.844437  2.720731
# 33                      0.076500  0.843866  2.714798
# 31                      0.155898  0.789748  2.707276
# 7                       0.029101  0.840482  2.659301
# 12                      0.019483  0.839795  2.637364
# 25                      0.019483  0.839795  2.637364
# 3                       0.014476  0.839438  2.621526
# 1                       0.013317  0.839355  2.617136
# 9                       0.025401  0.780782  2.615582
# 17                      0.024279  0.780702  2.613104
# 38                      0.024119  0.780691  2.612742
# 36                      0.023502  0.780647  2.611326
# 42                      0.009125  0.779620  2.561356
# 0                       0.016240  0.689924  2.473852
# 18                      0.015574  0.689876  2.471629
# 34                      0.014970  0.689833  2.469533
# 24                      0.011714  0.689601  2.456676
# 21                      0.010580  0.689520  2.451402
# 11                      0.009186  0.689420  2.444152
# 23                      0.008225  0.689352  2.438526
# 46                      0.008126  0.689345  2.437914
# 39                      0.029508  0.616051  2.425849
# 20                      0.026671  0.615849  2.420259
# 47                      0.019483  0.540515  2.319723
# 43                      0.013021  0.540054  2.298317
# 37                      0.012503  0.540017  2.296195
# 5                       0.009581  0.539808  2.282426
# 8                       0.008200  0.539710  2.274495
# 15                      0.005906  0.539546  2.258066
# 19                      0.002392  0.479860  2.153738
# 13                      0.014341  0.390508  2.124833
# 10                      0.014341  0.390508  2.124833
# 41                      0.013527  0.390450  2.121759
# 27                      0.010247  0.390216  2.107321
# 32                      0.000000  0.838404  1.882453
# 29                      0.000962  0.239913  1.791393
# 16                      0.000000  0.688764  1.728690
# 40                      0.000000  0.688764  1.728690
# 45                      0.000000  0.688764  1.728690

# %%
print("\n\nTop 3 by Weighted Sum:\n\n")
print(df9.sort_values(by = 'WS', ascending=False).iloc[0:3])
print("\n\nTop 3 by Weighted Product:\n\n")
print(df9.sort_values(by = 'WP', ascending=False).iloc[0:3])
# Out:
# Top 3 by Weighted Sum:
#
#
#                      Company Name  Credit Score Num  Location Score  \
# 22  Gulf States Refrigerated Stge               1.0           1.000
# 6             Americold Logistics               1.0           0.625
# 4                       Americold               1.0           1.000
#
#     Location Sales Volume Actual        WS        WP
# 22                      0.053972  0.932462  2.811873
# 6                       1.000000  0.932347  2.918702
# 4                       0.034748  0.931090  2.786748
#
#
# Top 3 by Weighted Product:
#
#
#                      Company Name  Credit Score Num  Location Score  \
# 6             Americold Logistics               1.0           0.625
# 22  Gulf States Refrigerated Stge               1.0           1.000
# 4                       Americold               1.0           1.000
#
#     Location Sales Volume Actual        WS        WP
# 6                       1.000000  0.932347  2.918702
# 22                      0.053972  0.932462  2.811873
# 4                       0.034748  0.931090  2.786748
